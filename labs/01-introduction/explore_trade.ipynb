# %% [markdown]
# # Lab 01: Explore a trade dataset
# Work through each step. Replace every `# TODO` with your own code or notes.

# %% [markdown]
# ## Step 1: Check your environment
# Run the cell below. It should print your Python version and the pandas version.

# %%
import sys
import pandas as pd

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)

# %% [markdown]
# ## Step 2: Load the data

# %%
df = pd.read_csv("../../data/trade_summary.csv")
# TODO: display the first 10 rows (hint: df.head(...))

# %% [markdown]
# ## Step 3: Describe the dataset
# How many rows and columns? What does each column mean? Which years, countries and product groups are covered?

# %%
# TODO: print the shape

# TODO: print the unique years (hint: df["year"].unique())

# TODO: print the unique reporters

# TODO: print the unique product groups

# %% [markdown]
# ## Step 4: A first summary
# Run the cell below, then describe in words what it shows.

# %%
df.groupby("year")[["exports_usd_m", "imports_usd_m"]].sum().round(0)

# %% [markdown]
# *TODO: what happened in 2020, and why might that be?*

# %% [markdown]
# ## Step 5: Analytical questions
# Write **five** analytical questions this dataset could answer. For each, note which columns you would need and whether the data is sufficient.
#
# | # | Question | Columns needed | Sufficient? |
# |---|---|---|---|
# | 1 | | | |
# | 2 | | | |
# | 3 | | | |
# | 4 | | | |
# | 5 | | | |

# %% [markdown]
# ## Step 6: What is missing?
# List two questions a policy colleague might ask that this dataset **cannot** answer, and what extra data you would need.
